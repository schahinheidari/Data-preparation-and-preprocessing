# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Automobile.csv')
data.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
sns.displot(data['wheel_base'])

# %%
data['wheel_base'].isnull().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# symboling              0
# normalized_losses      0
# make                   0
# fuel_type              0
# aspiration             0
# number_of_doors        0
# body_style             0
# drive_wheels           0
# engine_location        0
# wheel_base             0
# length                 0
# width                  0
# height                 0
# curb_weight            0
# engine_type            0
# number_of_cylinders    0
# engine_size            0
# fuel_system            0
# bore                   0
# stroke                 0
# compression_ratio      0
# horsepower             0
# peak_rpm               0
# city_mpg               0
# highway_mpg            0
# price                  0
# dtype: int64

# %%
sns.displot(data['price'])

# %%
sns.displot(data['horsepower'])

# %%
sns.jointplot(data['horsepower'], data['price'])
# Out:
# /home/shahin/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(data['horsepower'], data['wheel_base'])
# Out:
# /home/shahin/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data.corr()
# Out:
#                    symboling  normalized_losses  wheel_base    length  \
# symboling           1.000000           0.474993   -0.535987 -0.365404
# normalized_losses   0.474993           1.000000    0.007815  0.103659
# wheel_base         -0.535987           0.007815    1.000000  0.876024
# length             -0.365404           0.103659    0.876024  1.000000
# width              -0.242423           0.153752    0.814507  0.857170
# height             -0.550160          -0.335476    0.590742  0.492063
# curb_weight        -0.233118           0.178547    0.782097  0.880665
# engine_size        -0.110581           0.174788    0.572027  0.685025
# bore               -0.146355           0.007498    0.495210  0.610324
# stroke              0.018373           0.062666    0.148239  0.116745
# compression_ratio  -0.182196          -0.120846    0.250313  0.159733
# horsepower          0.075287           0.276665    0.372607  0.577923
# ...

# %%
sns.jointplot(data['horsepower'], data['wheel_base'], kind='hex')
# Out:
# /home/shahin/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.pairplot(data)

# %%
# https://seaborn.pydata.org/generated/seaborn.swarmplot.html
sns.swarmplot(data['fuel_type'],data['horsepower'])
# Out:
# /home/shahin/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/shahin/.local/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 6.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='fuel_type', ylabel='horsepower'>

# %%
# https://seaborn.pydata.org/generated/seaborn.boxplot.html
sns.boxplot(data['number_of_doors'], data['horsepower'], hue=data['fuel_type'])
# Out:
# /home/shahin/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='number_of_doors', ylabel='horsepower'>

# %%
# https://seaborn.pydata.org/generated/seaborn.barplot.html
sns.barplot(data['number_of_doors'], data['horsepower'], hue=data['fuel_type'])
# Out:
# /home/shahin/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='number_of_doors', ylabel='horsepower'>

# %%
sns.barplot(data['number_of_doors'], data['horsepower'])
# Out:
# /home/shahin/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='number_of_doors', ylabel='horsepower'>

# %%
sns.barplot(data['number_of_doors'], data['horsepower'], hue=data['engine_location'])
# Out:
# /home/shahin/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='number_of_doors', ylabel='horsepower'>
